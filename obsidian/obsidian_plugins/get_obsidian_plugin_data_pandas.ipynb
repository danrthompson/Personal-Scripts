# %%
# !pip install pathos
# Out:
# Collecting pathos
#   Obtaining dependency information for pathos from https://files.pythonhosted.org/packages/d8/08/ac94fa6f9eefe32963b8a54e573dab0dbc0d3df24fd34924bd9ce7eab7c4/pathos-0.3.1-py3-none-any.whl.metadata
#   Downloading pathos-0.3.1-py3-none-any.whl.metadata (11 kB)
# Collecting ppft>=1.7.6.7 (from pathos)
#   Obtaining dependency information for ppft>=1.7.6.7 from https://files.pythonhosted.org/packages/f0/f8/0a493dfdf73edbfe58cae1323aec72d0152f463c7a351bd285e9d500985c/ppft-1.7.6.7-py3-none-any.whl.metadata
#   Downloading ppft-1.7.6.7-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: dill>=0.3.7 in /Users/danthompson/Code/vscode/linting_env/lib/python3.10/site-packages (from pathos) (0.3.7)
# Collecting pox>=0.3.3 (from pathos)
#   Obtaining dependency information for pox>=0.3.3 from https://files.pythonhosted.org/packages/17/c7/ef7e37e5a895f5de068b408a52bee0710b1092574b6b4ab247a767e9fbd5/pox-0.3.3-py3-none-any.whl.metadata
#   Downloading pox-0.3.3-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.15 (from pathos)
#   Obtaining dependency information for multiprocess>=0.70.15 from https://files.pythonhosted.org/packages/35/a8/36d8d7b3e46b377800d8dec47891cdf05842d1a2366909ae4a0c89fbc5e6/multiprocess-0.70.15-py310-none-any.whl.metadata
#   Downloading multiprocess-0.70.15-py310-none-any.whl.metadata (7.2 kB)
# Downloading pathos-0.3.1-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 2.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 4.4 MB/s eta 0:00:00
# Downloading pox-0.3.3-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.7-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: ppft, pox, multiprocess, pathos
# Successfully installed multiprocess-0.70.15 pathos-0.3.1 pox-0.3.3 ppft-1.7.6.7

# %%
import pandas as pd
import requests
import time
from pathos.multiprocessing import ProcessingPool as Pool  # Import Pool from pathos
from datetime import datetime

# %%
TOKEN = "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"  # Replace with your GitHub Personal Access Token
HEADERS = {
    "Authorization": f"token {TOKEN}",
    "Accept": "application/vnd.github.v3+json",
}
# Define the maximum number of threads for parallel execution
MAX_THREADS = 10  # You can adjust this value

# %%
# Calculate days ago from a given timestamp string
def days_ago(timestamp_str):
    datetime_obj = datetime.strptime(timestamp_str, "%Y-%m-%dT%H:%M:%SZ")
    return (datetime.utcnow() - datetime_obj).days


def fetch_details_and_update_df_v3(data):
    idx, row = data
    new_row = row.copy()
    try:
        details = get_repo_details(row["repo_url"])
        if details:
            for key, value in details.items():
                new_row[key] = value
    except Exception as e:
        print(f"Error fetching details for {row['repo_url']}: {e}")
        for key in [
            "created_at",
            "updated_at",
            "repo_name",
            "repo_description",
            "readme_text",
            "stars",
        ]:
            new_row[key] = "N/A"
    return pd.DataFrame([new_row])


def get_repo_details(url):
    # Extract username and repo name from the URL
    parts = url.split("/")
    user, repo_name = parts[-2], parts[-1]

    # Fetch repository details
    repo_api_url = f"https://api.github.com/repos/{user}/{repo_name}"
    response = requests.get(repo_api_url, headers=HEADERS)
    if response.status_code != 200:
        print(f"Failed to fetch details for {url}. Status code: {response.status_code}")
        return None

    repo_data = response.json()

    # Fetch README details
    readme_api_url = f"https://api.github.com/repos/{user}/{repo_name}/readme"
    readme_response = requests.get(readme_api_url, headers=HEADERS)
    readme_text = ""
    if readme_response.status_code == 200:
        readme_data = readme_response.json()
        readme_text = requests.get(readme_data["download_url"]).text

    # Extract required details
    details = {
        "created_at": repo_data.get("created_at", ""),
        "updated_at": repo_data.get("updated_at", ""),
        "repo_name": repo_data.get("name", ""),
        "repo_description": repo_data.get("description", ""),
        "readme_text": readme_text,
        "stars": repo_data.get("stargazers_count", 0),
    }
    return details

# %%
df = final_df

# %%
# Load the data
df = pd.read_csv("~/Downloads/obsidian (1).csv", thousands=",", quotechar='"')

# %%
# Initial number of rows
initial_rows = df.shape[0]
initial_rows
# Out:
# 1141

# %%
# Drop rows with missing values
df.dropna(
    subset=["plugin_name", "plugin_author", "num_downloads", "description", "repo_url"],
    inplace=True,
)

# Number of rows dropped
dropped_rows = initial_rows - df.shape[0]
dropped_rows
# Out:
# 0

# %%
# Remove "By " from plugin_author
df["plugin_author"] = df["plugin_author"].str.replace("By\xa0", "")

df["num_downloads"] = (
    df["num_downloads"].str.replace(" downloads", "").str.replace(",", "").astype(int)
)

github_df = df[df["repo_url"].str.contains("github.com")]

print(len(github_df))
print(len(df))
# Out:
# 1141
# 1141

# %%
# Fetch details for each repo and append to the DataFrame in parallel
with Pool(processes=MAX_THREADS) as pool:
    results = pool.map(fetch_details_and_update_df_v3, df.iterrows())

# %%
# Add the new columns
df["created_days_ago"] = df["created_at"].apply(days_ago)
df["updated_days_ago"] = df["updated_at"].apply(days_ago)
df["short_description"] = (
    df["plugin_name"]
    + " "
    + df["repo_description"].fillna("")
    + " "
    + df["description"]
)
df["long_description"] = df["short_description"] + " " + df["readme_text"]

# Keep the desired columns
final_df = df[
    [
        "plugin_name",
        "num_downloads",
        "description",
        "stars",
        "short_description",
        "long_description",
        "created_at",
        "updated_at",
        "updated_days_ago",
        "created_days_ago",
    ]
]

final_df.head()
# Out:
#           plugin_name  num_downloads  \
# 0    Source Code Note            416
# 1           At People            313
# 2      Image Captions           4951
# 3        Scroll Speed           1430
# 4  Latex Environments          14980
#
#                                          description  stars  \
# 0        Helps you organize source code note easily.     11
# 1  Use the familiar @ notation to cross link to p...      7
# 2  Adds captions to images when there is alt-text...     53
# 3         Change the scroll speed in Obsidian notes.     16
# 4  Quickly insert and change LaTeX environments w...     50
#
#                                    short_description  \
# 0  Source Code Note The obsidian plugin can help ...
# 1  At People Obsidian plugin to use the familiar ...
# 2  Image Captions Adds captions to images when th...
# 3  Scroll Speed Obsidian Plugin to Change Scroll ...
# 4  Latex Environments Quickly insert and change l...
#
#                                     long_description            created_at  \
# 0  Source Code Note The obsidian plugin can help ...  2023-03-10T09:44:13Z
# 1  At People Obsidian plugin to use the familiar ...  2023-08-17T02:04:56Z
# 2  Image Captions Adds captions to images when th...  2023-01-04T16:41:19Z
# 3  Scroll Speed Obsidian Plugin to Change Scroll ...  2021-10-20T10:51:00Z
# 4  Latex Environments Quickly insert and change l...  2020-11-04T23:57:39Z
#
#              updated_at  updated_days_ago  created_days_ago
# 0  2023-06-21T10:23:48Z                67               170
# 1  2023-08-27T20:40:51Z                 0                11
# 2  2023-08-12T04:56:58Z                16               235
# 3  2023-07-28T19:19:48Z                30               676
# 4  2023-07-19T08:56:11Z                39              1026

# %%
# Combine all the mini DataFrames from the results into one DataFrame
final_df = pd.concat(results).reset_index(drop=True)
df = final_df

# %%
df.head()
# Out:
#    Unnamed: 0         plugin_name  num_downloads  \
# 0           0    Source Code Note            416
# 1           1           At People            313
# 2           2      Image Captions           4951
# 3           3        Scroll Speed           1430
# 4           4  Latex Environments          14980
#
#                                          description  stars  \
# 0        Helps you organize source code note easily.     11
# 1  Use the familiar @ notation to cross link to p...      7
# 2  Adds captions to images when there is alt-text...     53
# 3         Change the scroll speed in Obsidian notes.     16
# 4  Quickly insert and change LaTeX environments w...     50
#
#                                    short_description  \
# 0  Source Code Note The obsidian plugin can help ...
# 1  At People Obsidian plugin to use the familiar ...
# 2  Image Captions Adds captions to images when th...
# 3  Scroll Speed Obsidian Plugin to Change Scroll ...
# 4  Latex Environments Quickly insert and change l...
#
#                                     long_description            created_at  \
# 0  Source Code Note The obsidian plugin can help ...  2023-03-10T09:44:13Z
# 1  At People Obsidian plugin to use the familiar ...  2023-08-17T02:04:56Z
# 2  Image Captions Adds captions to images when th...  2023-01-04T16:41:19Z
# 3  Scroll Speed Obsidian Plugin to Change Scroll ...  2021-10-20T10:51:00Z
# 4  Latex Environments Quickly insert and change l...  2020-11-04T23:57:39Z
#
#              updated_at  updated_days_ago  created_days_ago
# 0  2023-06-21T10:23:48Z                67               170
# 1  2023-08-27T20:40:51Z                 0                11
# 2  2023-08-12T04:56:58Z                16               235
# 3  2023-07-28T19:19:48Z                30               676
# 4  2023-07-19T08:56:11Z                39              1026

# %%
# Save the updated DataFrame
df.to_csv("obsidian_with_github_details.csv", index=False)
print("Data fetching completed. Results saved to obsidian_with_github_details.csv.")
# Out:
# Data fetching completed. Results saved to obsidian_with_github_details.csv.

# %%
df.iloc[0]
# Out:
# plugin_name                                          Source Code Note
# plugin_author                                                 Waiting
# num_downloads                                                     416
# description               Helps you organize source code note easily.
# repo_url            https://github.com/waiting0324/obsidian-code-note
# created_at                                       2023-03-10T09:44:13Z
# updated_at                                       2023-06-21T10:23:48Z
# repo_name                                          obsidian-code-note
# repo_description    The obsidian plugin can help you organize sour...
# readme_text         # Obsidian Source Code Note Plugin\n\n[中文文檔](....
# stars                                                              11
# Name: 0, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1141 entries, 0 to 1140
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   plugin_name       1141 non-null   object
#  1   plugin_author     1141 non-null   object
#  2   num_downloads     1141 non-null   int64
#  3   description       1141 non-null   object
#  4   repo_url          1141 non-null   object
#  5   created_at        1141 non-null   object
#  6   updated_at        1141 non-null   object
#  7   repo_name         1141 non-null   object
#  8   repo_description  936 non-null    object
#  9   readme_text       1141 non-null   object
#  10  stars             1141 non-null   int64
# dtypes: int64(2), object(9)
# memory usage: 98.2+ KB

# %%
df.iloc[0]
# Out:
# plugin_name                                          Source Code Note
# plugin_author                                                 Waiting
# num_downloads                                                     416
# description               Helps you organize source code note easily.
# repo_url            https://github.com/waiting0324/obsidian-code-note
# created_at                                       2023-03-10T09:44:13Z
# updated_at                                       2023-06-21T10:23:48Z
# repo_name                                          obsidian-code-note
# repo_description    The obsidian plugin can help you organize sour...
# readme_text         # Obsidian Source Code Note Plugin\n\n[中文文檔](....
# stars                                                              11
# Name: 0, dtype: object

# %%
# Out:
# 451

# %%
pd.set_option("display.max_colwidth", 1000)
# show 100 rows at a time
pd.set_option("display.max_rows", 100)

# Filter rows where column 'a' is greater than 100
fdf = df
fdf = fdf[fdf["updated_days_ago"] < 60]
fdf = fdf[fdf["num_downloads"] > 1000]
fdf = fdf[fdf["created_days_ago"] < 250]
# fdf = fdf[fdf["stars"] > 0]
# fdf = fdf[fdf["short_description"].str.contains(r"\b(block|link|embedding|transclude|transclusion)\b", case=False, regex=True)]
print(len(fdf))

# Sort filtered rows by column 'b' in descending order
sorted_df = fdf.sort_values(by="created_days_ago", ascending=True)
# sorted_df = fdf.sort_values(by="num_downloads", ascending=False)

sorted_df = sorted_df[
    [
        "plugin_name",
        "short_description",
        "num_downloads",
        # "updated_days_ago",
        "created_days_ago",
    ]
]

sorted_df.head(100)
# Out:
# 97
#                                 plugin_name  \
# 507                     Editor Width Slider
# 611                                Importer
# 1107                           Colored Tags
# 939                             Code Styler
# 65                               Time Ruler
# 801                   Pieces for Developers
# 332                         Link with alias
# 1038                  Attachment Management
# 817   Last Modified Timestamp in Status Bar
# 1124                 Confluence Integration
# 859                                    Chem
# 296                            Colored Text
# 686                   Auto Template Trigger
# 101                              Slide Note
# 843                            Mood Tracker
# 655                                   Links
# 830                                 No Tabs
# 1020                          Telegram Sync
# 110                                 Whisper
# 1087                       GPT-LiteInquirer
# 1067                                Copilot
# 266             April's Automatic Timelines
# 17                                    Gemmy
# 869                         Semantic Search
# 10                               File Order
# 418                   Ultimate Todoist Sync
# 377                               AI Mentor
# 448                   Colorful Note Borders
# 45                               Code Files
# 599                         Page Properties
# 96                                   Avatar
# 1105                   Easy toggle sidebars
# 797                         Advanced Merger
# 107                 Reveal file in explorer
# 740                        Wikipedia Search
# 713                              Pseudocode
# 515                            Folder notes
# 963                       Dynamic Timetable
# 746                         Auto Classifier
# 578                               Companion
# 281                   Focus Active Sentence
# 1004                            OZ Calendar
# 585                           GPT Assistant
# 866                            AI Assistant
# 46                             AI Commander
# 670                              ChatGPT MD
# 1102                                  ibook
# 803                         Floating Search
# 500                                Home tab
# 1031                                 Gene 🧬
# 112                             MSG Handler
# 97                                     Marp
# 389                         Open In New Tab
# 1136                            Marp Slides
# 407                      Close Similar Tabs
# 1132                 Tasks Calendar Wrapper
# 826               WuCai highlights Official
# 903               Global Search and Replace
# 569                  Apple Books Highlights
# 292                   Awesome Brain Manager
# 53                           Journal Review
# 690                         Callout Manager
# 1078                                    Zen
# 604             Optimize Canvas Connections
# 618                           HK Code Block
# 1021                            Emoji Magic
# 1044              Fantasy Content Generator
# 243                             ProgressBar
# 747                    Double Colon Conceal
# 180                    Codeblock Customizer
# 1135                              File Diff
# 911                          Custom Classes
# 1040                         Awesome Reader
# 705                           Canvas Filter
# 261                              Tag Search
# 158                          Advanced Paste
# 914                          Unicode Search
# 1058                          Awesome Image
# 760                         Restore Tab Key
# 742                        🪝 Grappling Hook
# 241                        Reading comments
# 2                            Image Captions
# 988                          Habit Calendar
# 930                              Vim Toggle
# 336                             YTranscript
# 544                    Fuzzy Chinese Pinyin
# 795                     Canvas Conversation
# 592                           Reference Map
# 438                             Short links
# 286                             Task Marker
# 700                       Smart Connections
# 104                      Google Keep Import
# 900    Natural Language Syntax Highlighting
# 762                           Spoiler Block
# 697                                Omnivore
# 50                            Link Exploder
# 784                              Hints Flow
#
#                                                                                                                                                                                                                                                                                                                                              short_description  \
# 507                                                                                                                                                                              Editor Width Slider With this plugin you can set the line width of the editor in obsidian. Customize Obsidian's editor width with a slider for a tailored editing experience.
# 611                                                                                                                                                                          Importer Obsidian Importer lets you import notes from other apps and file formats into your Obsidian vault. Import data from Notion, Evernote, Google Keep, Bear, and HTML files.
# 1107                                                                                               Colored Tags Colorizes tags in different colors. Colorizes tags in different colors. The color depends on the tag content. Colors of nested tags are mixed with parent tags. Text color contrast is automatically matched to comply with AA level WCAG 2.1.
# 939                                                                                                                                                                                                             Code Styler A plugin for Obsidian.md for styling codeblocks and inline code Style codeblocks and inline code in reading view and editing view.
# 65                                                                    Time Ruler A drag-and-drop time ruler combining the best of a task list and a calendar view (integrates with Tasks, Full Calendar, and Dataview). A drag-and-drop time ruler combining the best of a task list and a calendar view (integrates with Tasks, Full Calendar, and Dataview).
# 801   Pieces for Developers Pieces' powerful extension for Obsidian-MD that allows users to access their code snippets directly within the Obsidian workspace Streamline your coding workflow in Obsidian with the Pieces For Developers plugin, offering powerful features for capturing, managing, translating, and enhancing code snippets. (Closed Source)
# 332                                                                                                                                                                                     Link with alias Obsidian plugin for handy creation of links and alias in front matter of target document Creates links and aliases in front matter of target document.
# 1038                                                                                                                                                                                                                   Attachment Management Attachment Management of Obsidian Attachment management plugin to custom the attachment path and auto rename etc.
# 817                                                                                                                                                                                                                                                   Last Modified Timestamp in Status Bar  Dynamic display of file modification timestamp in the status bar.
# 1124                                                                                                                                                      Confluence Integration Sync / Publish Obsidian Notes to Confluence Publish markdown content from Obsidian to Atlassian Confluence. It supports some Obsidian markdown extensions for richer content.
# 859                                                                                                                                                                                 Chem Chemistry support for Obsidian. Rendering SMILES strings into chemistry structures. Providing chemistry supports. Rendering SMILES strings into chemistry structures.
# 296                                                                                                                                                                                                                                                                                                                    Colored Text  Color the selected texts.
# 686                                                                                                                                                                                                                                                                          Auto Template Trigger  Automatically prompt for a template, when creating a note.
# 101                                                                                                                                                                                                                                                                                                Slide Note  Conveniently take notes on PDF course slides :P
# 843                                                                                                                                                                                                                      Mood Tracker mood tracking for obsidian.md Track your moods & emotions easily. Visualize tracked history and browse the past entries.
# 655                                                                                                                                                                                                                                                                                                 Links manipulate & manage obisidian links Manipulate links
# 830                                                                                                                                                                                                                                 No Tabs Obsidian extension trying to keep only one tab open at a time. Replaces the previous tab when creating a new note.
# 1020                                                                                                                                                                                                                                Telegram Sync Transfer messages and files from Telegram to Obsidian Transfer messages and files from Telegram to Obsidian.
# 110                                                                                                                                                                                                                                                               Whisper Speech-to-text in Obsidian using OpenAI Whisper Speech-to-text using OpenAI Whisper.
# 1087                                                                                        GPT-LiteInquirer Experience OpenAI ChatGPT assistance directly within Obsidian, drafting content without interrupting your creative flow. Experience OpenAI ChatGPT assistance directly within Obsidian, drafting content without interrupting your creative flow.
# 1067                                                                                                                                                                                                                                                                                      Copilot A ChatGPT Copilot in Obsidian A ChatGPT Copilot in Obsidian.
# 266                                                                                                                                                                                                                  April's Automatic Timelines Simple timeline generator plugin for story tellers using obsidian Simple timeline generator for story tellers
# 17                                                                                                                                                                                                                                                                              Gemmy  Obsidian Unhelper. 2023 April Fool's plugin brought to you by Obsidian.
# 869                                                                                                                                                                                                                                                  Semantic Search Semantic search for Obsidian.md Semantic search for files using OpenAI's text embeddings.
# 10                                                                                                                           File Order Obsidian plugin to reorder files with drag-and-drop by customizing a number-prefix in the filenames Use number-prefixes in your file names to define a custom order, and drag-and-drop the files to update that order.
# 418                                                                                                                                                                                                                                                           Ultimate Todoist Sync  This is the best Todoist task synchronization plugin for Obsidian so far.
# 377                                                                                                                                                                                                                                                  AI Mentor  Meet your open source AI mentor in Obsidian. Ask questions, get answers, and learn new things.
# 448                                                                                                                                                                                             Colorful Note Borders  Add customizable colorful borders to notes based on folder location or frontmatter metadata, enhancing visual organization in Obsidian.
# 45                                                                                                                                                                                                          Code Files Plugin for ObsidianMD to show and edit code files along other notes. Edit Code Files in Obsidian with VS Code's powerful Monaco Editor.
# 599                                                                                                                                                                                                                                                Page Properties A plugin that adds Logseq-like page tags to Obsidian Add page properties similar to Logseq.
# 96                                                                                                                                                                                                                                     Avatar An obsidian plugin for displaying an avatar image in front of your notes. Display an avatar image in your notes.
# 1105                                                                                                                                                                   Easy toggle sidebars  toggle both sidebars (double middle mouse click or own shortcut) or each sidebar clicking middle mouse button and moving mouse towards the corresponding sidebar.
# 797                                                                                                                                                                                                                                                                                                Advanced Merger  Merge a folder of notes for easier export.
# 107                                                                                                                                               Reveal file in explorer Clicking the header title reveal the active file in explorer Clicking header title reveal active file in explorer and (option) when opening file + option to fold other directories.
# 740                                                                                                                                                                                                          Wikipedia Search An Obsidian plugin to search for Wikipedia articles and link them. Search, link and open Wikipedia articles, all within the app!
# 713                                                                                                                                                                                                  Pseudocode An obsidian plugin that helps to render a LaTeX-style pseudocode inside a code block. Helps render LaTeX-style pseudocode inside a code block.
# 515                                                                               Folder notes Create notes within folders that can be accessed without collapsing the folder, similar to the functionality offered in Notion. Create notes within folders that can be accessed without collapsing the folder, similar to the functionality offered in Notion.
# 963                                                                                                              Dynamic Timetable Calculate the estimated completion time from the estimated task time and dynamically create a timetable. Calculate the estimated time of completion from the estimated time of the task and dynamically create a timetable.
# 746                                                                                             Auto Classifier Auto classification plugin for Obsidian using ChatGPT. Automatically classify tag from your notes using ChatGPT API. It analyze your note (It can be title, frontmatter, content or selected area) and automatically insert tag where you set.
# 578                                                                                                                                                                        Companion Autocomplete your obsidian notes with AI, including ChatGPT, through a copilot-like interface. Autocomplete with AI, including ChatGPT, through a copilot-like interface.
# 281                                                                                                                                                                                                                              Focus Active Sentence Highlight the active sentence in Obsidian.md Highlight the sentence the cursor is currently resting on.
# 1004                                                                                                                                                                                                                                                                                  OZ Calendar  View your notes in Calendar using any YAML key with a date.
# 585                                                                                                                                                              GPT Assistant Ask GPT from your notes and get personalized answers based on your knowledge base. Use a GPT-3 based model on your notes and get personalized answers from your knowledge base.
# 866                                                                                                                                                                                                                                                                            AI Assistant AI Assistant Plugin for Obsidian AI Assistant plugin for Obsidian.
# 46                                                                                                                                                                                                                   AI Commander  Generate audio transcripts, images, and text in context of PDF attachments or web search results using OpenAI and Bing API.
# 670                                                                                                                                                                                                                             ChatGPT MD A (nearly) seamless integration of ChatGPT into Obsidian. A (nearly) seamless integration of ChatGPT into Obsidian.
# 1102                                                                                                                                                                                                            ibook export mac ibook annotations/hightlights to obsidian vault Export your Apple iBook hightlights and annotations into your Obsidian vault.
# 803                                                                                                                                                                                                                      Floating Search A plugin for searching text by using Obsidian default search view. Search text by using Obsidian default search view.
# 500                                                                                                                                                                                                                                     Home tab  A browser-like search tab for your local files in Obsidian.  A browser-like search tab for your local files.
# 1031                                                                                                                                                                                                                                                                            Gene 🧬 An AI assistant plugin for Obsidian Generate text using the OpenAI API.
# 112                                                                                                                                                                                                                                                                      MSG Handler  Easily display and search MSG files from Outlook in your Obsidian vault.
# 97                                                                                                                                                                                                                                                                                    Marp Plugin to use Marp with Obsidian Plugin for using Marp on Obsidian.
# 389                                                                                                                                                                                                                                                                                                    Open In New Tab  Opens files in new tabs like a browser
# 1136                                                                                                                                                                                                                                                  Marp Slides Create markdown-based Marp presentations in Obsidian  Create Marp presentations in Obsidian.
# 407                                                                                                                                                                                                                         Close Similar Tabs Close Similar tabs Avoid to have a file opened several times in your tabs. (+setting: by window or everywhere).
# 1132                                                                                                           Tasks Calendar Wrapper This plugin currently provides a timeline view to display your tasks from your obsidian valut, with customizable filters and renderring options. Simple wrapper for Obsidian Tasks Calendar and Obsidian Tasks Timeline.
# 826                                                                                                                                                                                                                    WuCai highlights Official WuCai highlights Official, for Sync highlights into your obsidian notes Sync WuCai highlights into your notes
# 903                                                                                                                                                                                                              Global Search and Replace A plugin to do a global search and replace in all your Obsidian vault files. Search and replace in all vault files.
# 569                                                                                                                                                                                                                                        Apple Books Highlights Sync your Apple Books highlights in Obsidian Sync your Apple Books highlights automatically.
# 292                                                                                                        Awesome Brain Manager A plugin that tries to solve all the trivial problems most people usually encountered in obsidian. 旨在解决大多数人在Obsidian中遇到的所有琐碎问题 A toolkit tries to solve all the trivial problems most people usually encountered in Obsidian.
# 53                                                                                                                                                                     Journal Review Review your daily notes on their anniversaries, like "what happened today last year" Review your daily notes on their anniversaries, like what happened today last year.
# 690                                                                                                                                                                                                                             Callout Manager An Obsidian.md plugin that makes creating and configuring callouts easy. Easily create and customize callouts.
# 1078                                                                                                                                                                                                                                                                  Zen A focus mode Obsidian plugin. Inspired by "iA Writer". A focus mode Obsidian plugin.
# 604                                                                                                                                                               Optimize Canvas Connections An Obsidian plugin that declutters a canvas by reconnecting notes using their nearest edges Declutters a canvas by reconnecting notes using their nearest edges.
# 618                                                                                                                                                              HK Code Block Obsidian plugin developed by Heekang Park; Make code block looking good on reading view Obsidian plugin developed by Heekang Park; Make code block looking good on reading view
# 1021                                                                                                                                                                                                                              Emoji Magic Makes it easier to add emojis using an improved keyword search Easily add emoji, with a powerful keyword search.
# 1044                                                                                                                                                                                                       Fantasy Content Generator a fantasy name generator for Obsidian A Fantasy Content Generator for Obsidian for All Your TTRPG / World Building Needs.
# 243                                                                                                                                                                                                                        ProgressBar Code block plugin for Obsidian generating a progress bar Render CodeBlock into a ProgressBar based on Time or Manually.
# 747                                                                                                Double Colon Conceal Obsidian plugin to display double colon (i.e. Dataview inline fields) as a single colon for more natural reading experience. Display double colon (i.e. Dataview inline fields) as a single colon for more natural reading experience.
# 180                                                                                                                                                                                                                             Codeblock Customizer Codeblock Customizer plugin for Obsidian Customize your code blocks in editing, and reading mode as well.
# 1135                                                                                                                                                                                                                               File Diff View the difference between two files within Obsidian. View the differences between two files with merge options.
# 911                                                                                                                                Custom Classes A minimal Obsidian plugin that allows you to add your own HTML classes to chosen Markdown elements directly from your notes. Add your own HTML classes to chosen Markdown elements directly from your notes.
# 1040                                                                                                                                                                                                                                                                              Awesome Reader Make Obsidian a proper Reader. Make Obsidian a proper Reader.
# 705                                                                                                                    Canvas Filter Obsidian Canvas plugin that let's you show only pages / arrows with specific tags / colors / connections. Lets you filter Canvas to only show items of specific color, tags or only connected to currently selected node.
# 261                                                                                                                                                                                                                                                                                                     Tag Search Fuzzy-find your tags! Fuzzy-find your tags!
# 158                                                                                                                                                                                                       Advanced Paste Advanced pasting functionality for obsidian Provides advanced paste commands and enables you to create custom transforms for pasting.
# 914                                                                                                                                                                                                                                  Unicode Search Obsidian plugin for simple Unicode character search Search and insert Unicode characters into your editor.
# 1058                                                                                                                                                                                                                                                 Awesome Image One-stop solution for image management. One-stop solution for image management and viewing.
# 760                                                                                                                                                                                            Restore Tab Key Restore tab key behaviour: tab key inserts a tab, the way it should be. Restore tab key behaviour: tab key inserts a tab, the way it should be.
# 742                                                                                                       🪝 Grappling Hook Obsidian Plugin for blazingly fast file switching. For those who find the Quick Switcher still too slow. Blazingly fast file switching to bookmarked files. For people for whom using the Quick Switcher still takes too much time.
# 241                                                                                               Reading comments Reading comments, for consuming books or large articles in markdown with https://obsidian.md/.  Plugin allows you to create inline comments while you read books or articles in Obsidian. Comments could be grouped hierarchically by tags.
# 2                                                                                                                                                                                                                            Image Captions Adds captions to images when there is alt-text specified Adds captions to images when there is alt-text specified.
# 988                               Habit Calendar Monthly Habit Calendar for DataviewJS. This plugin helps you render a calendar inside DataviewJS code block, showing your habit status within a month. Monthly Habit Calendar for DataviewJS. This plugin helps you render a calendar inside DataviewJS code block, showing your habit status within a month.
# 930                                                                                                     Vim Toggle This is a plugin that adds the ability to toggle on and off vim into obsidian with a nice notice to let you know when you switched. (It toggles vim on/off) Allows for the the toggling and customization of said toggling within settings.
# 336                                                                                                                                                                                                                                                                                             YTranscript  Easily fetch transcription for any YouTube video.
# 544                                                                                                                                                                                                                                                                           Fuzzy Chinese Pinyin  Provide the function of fuzzy search using Chinese Pinyin.
# 795                                                                                                                                                                                                       Canvas Conversation A plugin for Obsidian that allows you to create a canvas conversation using ChatGPT. Create a canvas conversation using ChatGPT.
# 592                                                                                                                                                                                                               Reference Map Reference and citation map for literature review and discovery Reference and citation map for literature review and discovery.
# 438                                                                                                                                                                                                                        Short links An Obsidian plugin to display short internal links. Display short internal links to files, notes, headings, and blocks.
# 286                                  Task Marker An [Obsidian](https://obsidian.md/) plugin to change task status and append text with hotkeys and right-click context menu. Change task status and append text with hotkeys and context menu. Create, complete, cancel and mark tasks, cycle among configured task statuses, and append text (automatically).
# 700                                                   Smart Connections Chat with your notes in Obsidian! Plus, see what's most relevant in real-time! Interact and stay organized. Powered by OpenAI ChatGPT, GPT-4 & Embeddings. Chat with your notes & find links to similar content using artificial intelligence like OpenAI Embeddings, GPT-3.5 & GPT-4.
# 104                                                                                                                                                                                          Google Keep Import Imports Google Keep backup files Allows import of Google Keep backup json files and their attachments. Can also be used to import other files.
# 900                                                                                                                                                             Natural Language Syntax Highlighting Highlight adjectives, nouns, adverbs, verbs, and conjunctions in Obsidian.md Highlight adjectives, nouns, adverbs, verbs, and conjunctions in the editor.
# 762                                                                                                                                                                                                                  Spoiler Block Just a simple obsidian plugin to hide information until you want to reveal it Hide information until you want to reveal it.
# 697                                                                                                                                                                                                                                                      Omnivore Obsidian plugin to fetch articles and highlights from Omnivore Omnivore plugin for Obsidian.
# 50                                                                                                                                                                                 Link Exploder  Link Exploder creates a canvas from a note, embedding it's incoming (i.e. backlinks) and outgoing links onto the canvas (as well as the their linked notes).
# 784                                                                                   Hints Flow Save data directly to Obsidian with a specified template. Capture from Telegram, WhatsApp, Slack, Email, SMS, Raycast and more. Save data directly to Obsidian with specified template. Capture from Telegram, WhatsApp, Slack, Email, SMS, Raycast and more.
#
#       num_downloads  created_days_ago
# 507            1026                44
# 611           11500                47
# 1107           2032                50
# 939            1302                52
# 65             2125                84
# 801            1696                87
# 332            1009               103
# 1038           1599               113
# 817            1155               122
# 1124           1654               123
# 859            1366               124
# 296            8534               125
# 686            1641               126
# 101            1695               133
# 843            1856               135
# 655            4183               141
# 830            1068               142
# 1020           2361               145
# 110            4720               146
# 1087           1085               150
# 1067          25721               150
# 266            3524               151
# 17             1724               151
# 869            1224               152
# 10             4478               152
# 418            2189               153
# 377            1073               154
# 448            1821               155
# 45             1786               159
# 599            1194               161
# 96             1345               162
# 1105           2674               162
# 797            1212               164
# 107            2036               164
# 740            2968               165
# 713            1618               167
# 515            9302               168
# 963            2338               168
# 746            2456               168
# 578            3293               169
# 281            1151               169
# 1004           2995               170
# 585            1508               170
# 866            2818               170
# 46             4423               174
# 670           21585               176
# 1102           5696               177
# 803            2208               179
# 500            6642               181
# 1031           1529               181
# 112            1291               185
# 97             3313               186
# 389            3195               188
# 1136           2222               189
# 407            9175               193
# 1132           7631               193
# 826            2785               195
# 903            5981               197
# 569            1070               197
# 292            1435               198
# 53             1580               201
# 690            6583               202
# 1078           1510               205
# 604            3016               206
# 618            1146               210
# 1021           2978               211
# 1044           4061               211
# 243            1596               211
# 747            1284               213
# 180            3013               214
# 1135           1275               214
# 911            1508               216
# 1040           1527               216
# 705            2462               218
# 261            1453               219
# 158            2999               224
# 914            1777               226
# 1058           1915               226
# 760            1623               227
# 742            1876               230
# 241            1306               231
# 2              4951               235
# 988            2059               236
# 930            1117               237
# 336            4088               237
# 544            1577               238
# 795            2550               240
# 592            3519               242
# 438            3685               243
# 286            4382               243
# 700           46706               244
# 104            1591               244
# 900            2254               248
# 762            1649               248
# 697           20012               249
# 50             4944               249
# 784            2307               249

# %%
sorted_df.head(50)
# show more of the description
# Out:
#                           plugin_name  \
# 184                   Advanced Slides
# 958                     Remotely Save
# 58                         Omnisearch
# 426                    Text Generator
# 90                       Hover Editor
# 1003               Zotero Integration
# 954                          Projects
# 577                           MAKE.md
# 121                          DataLoom
# 236                     Full Calendar
# 354                         Commander
# 579                       ExcaliBrain
# 808                 Obsidian42 - BRAT
# 894                  Fantasy Calendar
# 307                   Editing Toolbar
# 157         Obsidian Enhancing Export
# 413              Self-hosted LiveSync
# 5               Multi-Column Markdown
# 411           Excel to Markdown Table
# 392                    Obsidian Memos
# 613                 Footnote Shortcut
# 573                         TagFolder
# 386                     Metadata Menu
# 1043                      Latex Suite
# 895                     Custom Frames
# 446                   Settings Search
# 700                 Smart Connections
# 1122            Markdown Table Editor
# 860                       Book Search
# 520             Plugin Update Tracker
# 960                    Text Extractor
# 967                  Heatmap Calendar
# 502                   Google Calendar
# 629                     Quiet Outline
# 548             Mousewheel Image zoom
# 439                    Local REST API
# 947                      Execute Code
# 394                          Completr
# 35    Obsidian42 - Strange New Worlds
# 698                               Ava
# 498                     Weread Plugin
# 977                     Mermaid Tools
# 1067                          Copilot
# 464                   Icon Shortcodes
# 94                   Novel Word Count
# 270                  Obsidian Columns
# 670                        ChatGPT MD
# 521                Paste image rename
# 897                          Waypoint
# 697                          Omnivore
#
#                                                                                                                                                                                                                                                                      description  \
# 184                                                                                                                                                                                                                             Create Markdown-based presentations in Obsidian.
# 958                                                                                                                                       Yet another unofficial plugin allowing users to sync notes between local device and the cloud service (S3, Dropbox, webdav, OneDrive).
# 58                                                                                                                                                                                                                  Intelligent search for your notes, PDFs, and OCR for images.
# 426                                                                                                                                                                                  Text generator is a handy plugin that helps you generate text content using GPT-3 (OpenAI).
# 90                                                                                                                                                                                                Transform the Page Preview hover popover into a fully working editor instance.
# 1003                                                                                                                                                                                        Insert and import citations, bibliographies, notes, and PDF annotations from Zotero.
# 954                                                                                                                                                                                                                                             Project management for Obsidian.
# 577                     Make.md brings you features that supercharges Obsidian. Sort your files in custom order and add file icons using Spaces. Edit inline embeds with Flow Editor. And style your text and add new Markdown blocks without writing Markdown using Maker Mode.
# 121                                                                                                                                                           Weave together data from diverse sources into a cohesive table view. Inspired by Excel spreadsheets and Notion.so.
# 236                                                                                                                                                                                  Keep events and manage your calendar alongside all your other notes in your Obsidian vault.
# 354                                                                                                                                                                   Customize your workspace by adding commands everywhere, create macros and supercharge your mobile toolbar.
# 579   ExcaliBrain is inspired by TheBrain and Breadcrumbs. It is an interactive, structured mind-map of your Obsidian vault generated based on the folders and files in your vault by interpreting the links, Dataview fields, tags and YAML frontmatter in your Markdown files.
# 808                                                                                                                                                                                                                       Easily install a beta version of a plugin for testing.
# 894                                                                                                                                                                                                                                               Fantasy calendars in Obsidian!
# 307                                                                                      The Editing Toolbar is modified from cmenu, which provides more powerful customization settings and has many built-in editing commands to be a MS Word-like toolbar editing experience.
# 157                                                                                                                                                 A enhancing export plugin base on pandoc for Obsidian. It allows to export to formats like HTML, DOCX, ePub and PDF or Hugo.
# 413                                                          Community implementation of self-hosted livesync. Reflect your vault changes to some other devices immediately. Please make sure to disable other synchronize solutions to avoid content corruption or duplication.
# 5                                                                                                                                                                            Create Markdown documents with multiple columns of content viewable within Obsidian's preview mode.
# 411                                                                                                                                                    Paste data from Microsoft Excel, Google Sheets, Apple Numbers and LibreOffice Calc as Markdown tables in Obsidian editor.
# 392                                                                                                                                                                                                                                              Works perfect with your journal
# 613                                                                                                                                                                                                                               Makes creating footnotes in Obsidian more fun!
# 573                                                                                                                                                                                                                                                         Show tags as folder.
# 386                                                                                                                                                                               For data quality enthusiasts and Dataview users: access and manage the metadata of your notes.
# 1043                                                                                                                                                               Make typesetting LaTeX math as fast as handwriting through snippets, text expansion, and editor enhancements.
# 895                                                                                                                                                      Turns web apps into panes using iframes with custom styling. Also comes with presets for Google Keep, Todoist and more.
# 446                                                                                                                                                                                                                                        Globally search settings in Obsidian.
# 700                                                                                                                                                  Chat with your notes & find links to similar content using artificial intelligence like OpenAI Embeddings, GPT-3.5 & GPT-4.
# 1122                                                                                                                               Provides an editor for Markdown tables. It can open CSV, Microsoft Excel/Google Sheets data as Markdown tables from Obsidian Markdown editor.
# 860                                                                                                                                                                                                                                       Helps you find books and create notes.
# 520                                                                                                                                                                                                 Know when installed plugins have updates and evaluate the risk of upgrading.
# 960                                                                                                                                                                                        A (companion) plugin to facilitate the extraction of text from images (OCR) and PDFs.
# 967                                                                                                                                    Activity Year Overview for DataviewJS, Github style – Track Goals, Progress, Habits, Tasks, Exercise, Finances, Dont Break the Chain etc.
# 502                                                                                                                                                                                                                     Interact with your Google Calendar from inside Obsidian.
# 629                                                                                                                                                           Make outline quiet and more powerful, including no-auto-expand, rendering heading as Markdown, and search support.
# 548                                                                                                                                                                                                          Enables you to increase/decrease the size of an image by scrolling.
# 439                                                                                                                                                                                          Unlock your automation needs by interacting with your notes over a secure REST API.
# 947                                                                                                                                                                                                                                         Execute code snippets within a note.
# 394                                                                                                                                                                                 Provides advanced auto-completion functionality for LaTeX, frontmatter and standard writing.
# 35                                                                                                                                                                                                 Revealing networked thought and the strange new worlds created by your vault.
# 698                                                                                                                                                                                                                                      Quickly format your notes with ChatGPT.
# 498                                                                                                                                                                                                                              Sync Tencent Weread highlights and annotations.
# 977                                                                                                                                                                                     Improved Mermaid.js experience for Obsidian: visual toolbar with common elements & more.
# 1067                                                                                                                                                                                                                                              A ChatGPT Copilot in Obsidian.
# 464                                                                                                                                                                                                                               Insert emoji and custom icons with shortcodes.
# 94                                                                                                                                               Displays a word count, page count, creation date, or other statistic for each file, folder and vault in the File Explorer pane.
# 270                                                                                                                                                                                                                                         Create columns in Obsidian Markdown.
# 670                                                                                                                                                                                                                    A (nearly) seamless integration of ChatGPT into Obsidian.
# 521                                                                                                                                                                                                          Rename image after pasting, support name pattern and auto renaming.
# 897                                                                                                                                         Easily generate dynamic MOCs in your folder notes. Enables folders to show up in the graph view and removes the need for messy tags!
# 697                                                                                                                                                                                                                                                Omnivore plugin for Obsidian.
#
#       num_downloads  updated_days_ago
# 184          629499                 0
# 958          230592                 0
# 58           183074                 0
# 426          129142                 0
# 90           127499                 0
# 1003         122480                 0
# 954          119997                 1
# 577          118258                 0
# 121          116041                 0
# 236          109914                 0
# 354           88426                 0
# 579           82891                 0
# 808           77387                 0
# 894           72999                11
# 307           72880                 0
# 157           72639                 0
# 413           68220                 0
# 5             64796                 1
# 411           64707                 6
# 392           59582                 0
# 613           59130                 0
# 573           56337                 0
# 386           55794                 0
# 1043          53935                 1
# 895           49612                 1
# 446           47031                 6
# 700           46706                 0
# 1122          39945                11
# 860           38460                 0
# 520           38195                 6
# 960           37927                 0
# 967           36527                 1
# 502           36460                 0
# 629           33828                 7
# 548           33454                13
# 439           32995                 0
# 947           30680                 2
# 394           29641                10
# 35            26391                 2
# 698           26324                 0
# 498           26019                 2
# 977           25892                 0
# 1067          25721                 0
# 464           25641                 0
# 94            25455                38
# 270           24554                13
# 670           21585                 3
# 521           21548                 2
# 897           20085                 2
# 697           20012                 0

# %%
df.to_csv("obsidian_with_github_details.csv", index=True)

# %%
ls
# Out:
# aliases.zsh                       plugins/
# antigen.log                       secrets.sh
# fzf.zsh                           secrets.zsh@
# obsidian_with_github_details.csv  zsh_omz.code-workspace
# old_zshrc_configs.txt             zshrc
# package_plugin_setup.zsh          zshrc.zwc
# personal_zsh_configs.zsh

# %%
df = pd.read_csv("obsidian_plugins_with_repo_details.csv")
